# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %matplotlib inline

# %%
recent_grads=pd.read_csv('recent-grads.csv')

# %%
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major  Total    Men  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339   2057
# 1     2        2416             MINING AND MINERAL ENGINEERING    756    679
# 2     3        2415                  METALLURGICAL ENGINEERING    856    725
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258   1123
# 4     5        2405                       CHEMICAL ENGINEERING  32260  21239
#
#    Women Major_category  ShareWomen  Sample_size  Employed      ...        \
# 0    282    Engineering    0.120564           36      1976      ...
# 1     77    Engineering    0.101852            7       640      ...
# 2    131    Engineering    0.153037            3       648      ...
# 3    135    Engineering    0.107313           16       758      ...
# 4  11021    Engineering    0.341631          289     25694      ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major  Total   Men  Women  \
# 168   169        3609                 ZOOLOGY   8409  3050   5359
# 169   170        5201  EDUCATIONAL PSYCHOLOGY   2854   522   2332
# 170   171        5202     CLINICAL PSYCHOLOGY   2838   568   2270
# 171   172        5203   COUNSELING PSYCHOLOGY   4626   931   3695
# 172   173        3501         LIBRARY SCIENCE   1098   134    964
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count,columns=recent_grads.shape

# %%
recent_grads=recent_grads.dropna()

# %%
cleaned_data_count,columns=recent_grads.shape

# %%
print('Before cleaning data',raw_data_count)
print('After cleaning data',cleaned_data_count)
# Out:
# Before cleaning data 173
# After cleaning data 172

# %% [markdown]
# ==> Only one row contained missing values and was dropped

# %%
fig=plt.figure(figsize=(20,20))
ax1=fig.add_subplot(3,2,1)
ax2=fig.add_subplot(3,2,2)
ax3=fig.add_subplot(3,2,3)
ax4=fig.add_subplot(3,2,4)
ax5=fig.add_subplot(3,2,5)
ax6=fig.add_subplot(3,2,6)


ax1.scatter(recent_grads.Sample_size,recent_grads.Median,color='red')
ax1.set_title("Sample_size & Median",fontweight='bold',fontsize=10)
ax1.set_xlabel("Sample_size",fontsize=10)
ax1.set_ylabel("Median",fontsize=10)

ax2.scatter(recent_grads.Sample_size,recent_grads.Unemployment_rate,color='green')
ax2.set_title("Sample_size & Unemployment_rate",fontweight='bold',fontsize=10)
ax2.set_xlabel("Sample_size",fontsize=10)
ax2.set_ylabel("Unemployment_rate",fontsize=10)

ax3.scatter(recent_grads.Full_time,recent_grads.Median,color='yellow')
ax3.set_title("Full_time & Median",fontweight='bold',fontsize=10)
ax3.set_xlabel("Full_time",fontsize=10)
ax3.set_ylabel("Median",fontsize=10)

ax4.scatter(recent_grads.ShareWomen,recent_grads.Unemployment_rate,color='purple')
ax4.set_title("ShareWomen & Median",fontweight='bold',fontsize=10)
ax4.set_xlabel("ShareWomen",fontsize=10)
ax4.set_ylabel("Median",fontsize=10)

ax5.scatter(recent_grads.Men,recent_grads.Median,color='blue')
ax5.set_title("Men & Median",fontweight='bold',fontsize=10)
ax5.set_xlabel("Men",fontsize=10)
ax5.set_ylabel("Median",fontsize=10)

ax6.scatter(recent_grads.Women,recent_grads.Median,color='orange')
ax6.set_title("Women & Median",fontweight='bold',fontsize=10)
ax6.set_xlabel("Women",fontsize=10)
ax6.set_ylabel("Median",fontsize=10)

plt.show()

# %%
cols=['Sample_size','Median','Employed','Full_time','ShareWomen','Unemployment_rate','Men','Women']
fig=plt.figure(figsize=(20,20))
for i in range(len(cols)):
    ax=fig.add_subplot(4,2,i+1)
    ax.hist(recent_grads[cols[i]])
plt.show()

# %%
cols=['Sample_size','Median','Employed','Full_time','ShareWomen','Unemployment_rate','Men','Women']
fig=plt.figure(figsize=(20,20))
#for i in range(len(cols)):
ax1=fig.add_subplot(4,2,1)
ax1.hist(recent_grads[cols[0]])
ax1.set_title('Sample_size')
                    
ax2=fig.add_subplot(4,2,2)
ax2.hist(recent_grads[cols[1]])
ax2.set_title('Median')

ax3=fig.add_subplot(4,2,3)
ax3.hist(recent_grads[cols[2]])
ax3.set_title('Employed')

ax4=fig.add_subplot(4,2,4)
ax4.hist(recent_grads[cols[3]])
ax4.set_title('Full_time')

ax5=fig.add_subplot(4,2,5)
ax5.hist(recent_grads[cols[4]])
ax5.set_title('ShareWomen')
                      
ax6=fig.add_subplot(4,2,6)
ax6.hist(recent_grads[cols[5]])
ax6.set_title('Unemployment_rate')
                      
ax7=fig.add_subplot(4,2,7)
ax7.hist(recent_grads[cols[6]])
ax7.set_title('Men')
                      
ax8=fig.add_subplot(4,2,8)
ax8.hist(recent_grads[cols[7]])
ax8.set_title('Women')
                      
plt.show()

# %% [markdown]
# ==> What's the most common median salary range?
# ==>What percent of majors are predominantly male? Predominantly female?

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(6,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3864791240>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f38646a91d0>]], dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median','Unemployment_rate']], figsize=(9,9))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3864fc1b38>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f38643eca20>]], dtype=object)

# %%
#The first ten rows
recent_grads[:10].plot.bar(x='Major', y='Women')

# %%
recent_grads[162:].plot.bar(x='Major', y='Women')

# %%
recent_grads[162:].plot.bar(x='Major', y='Unemployment_rate')
